# %% [markdown]
# # **Team Nature**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# We were given the task of coming up with the best neighborhood in Pittsburgh. We used data from the Western Pennsylvania Regional Data Center to determine best neighborhood. Each member picked one dataset to analyze and then combined them to make a metric. We ended up with four datasets, each detailing a different metric on what neighborhood in Pittsburgh is best. We used datasets that had the number of parks, number of trees, least tax deliquency, and least condemed properties. These were our final datasets, but we had some others we considered as well.
#
# Some alternative datasets we considered for our metric included number of ball fields, gyms, air quality, etc. These metrics are similar to some of the ones we choose, but we felt they wete not as representative as we liked. To clarify, the park dataset is a more overarching metric than ball fields or gyms, especially when we wanted this metric to provide people who live in these neighborhood's an outdoor place to relax, exercise, and enjoy life.
#
# We came up with our combined metric after analyzing each member’s choice, and then finding a way to fit them all together. We ended up deciding that our nature data descrived how enjoyable the neighborhood was and the tax deliquency and condemned properties descrived how lively the neighborhood was.

# %% [markdown]
# ## **Metric**

# %% [markdown]
# **The Metric:** enjoyable/liveliness
# We decided to measure four features within our metric: most parks, most trees, least tax delinquency, and least condemned properties. The most parks and most trees are within the enjoyable aspect of our metric, and the least tax deliquency and least condemned properties are within the liveliness aspect of our metric. The enjoyable aspect describes people's ability to have enjoyable place to go walk, relax, exercise, or play sports. The liveliness aspect describes how much activity is going on in the neighborhood. If there is lower tax deliquency and lower condemnded properties, the neighborhood should be more lively.
#
# The four datasets we chose are City of Pittsburgh Parks, City of Pittsburgh Trees, City of Pittsburgh Property Tax Delinquency, and Condemned and Dead-End Properties. Each dataset provides data on one of the four features.
#
# The reason we decided on the enjoayable/liveliness metric is because between all of our metrics we have some sort of theme (nature/parks). By combining the metrics to find places with a large amount of green space between trees and parks, it gives a good representation of somewhere we would find enjoyable to live. Likewise, places with tax delinquent and condemned properties impact the liveliness of the area. We worked to find a neighborhood that gave a good balance between number of parks, lots of trees, and few delinquent or condemned properties.

# %% [markdown]
# ## **Best Neighborhood**

# %% [markdown]
# #### The Best Neighborhood: Beechview
# After looking through all our data we found that Beechview was always in a higher portions of our data. It ranks first in parks, near top in trees, and tied for the top in least tax delinquency. The only place it struggles is in dead end properties, but it's still within the top 20. Overall, Beechview is the most enjoyable and lively neighborhood in the Pittsburgh area and is a great representation of all our data.

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# The overall conclusion, as seen in the best neighborhood section, was Beechview. However, this did not exactly fit with each of our own conclusions/opinions. Landon's opinion of best neighborhood was Squirrel Hill and was suprised when the parks dataset determined that Beechview was number one. However, he concluded that this was due to not including an acreage metric in the dataset. For the tree dataset, selected by Tyler, the best neighborhood was not at the top of the dataset but rather around the top 75%. His initial conclusion was that Squirrel Hill South would be number one, not Beechview. For the condemned property dataset, selected by Peter, there were multiple neighborhoods that could've been the best according to him. These neighborhoods included Summer Hill, Middle Hill, Northview Heights, South Shore, and Swisshelm Park. For the tax deliquency dataset, selected by Finn, there wasn't one best neighborhood due to a large number of ties. However, Beechview was among those tied for the least tax deliquency. So although some of our own conclusions differed from the final conclusion, Beechview is still a good representative of all our data.

# %% [markdown]
# ### Importing Datasets

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Trees.csv")
# Out:
# /scratch/slurm-35315/ipykernel_3718823/2737032781.py:4: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Trees.csv")

# %% [markdown]
# ### **Dataset 1 : Number of Registered Trees in Each Pittsburgh Neighborhood**

# %% [markdown]
# Counting the number of trees in each neighborhood and ranking them based on it.

# %%
df = df.sort_values(by="neighborhood")
df.head(10)
# Out:
#          _id          id address_number street        common_name  \
# 32362  32363   313601039            NaN    NaN          Elm: spp.
# 32368  32369   894735059            NaN    NaN  Oak: Northern Red
# 32369  32370  1039721474            NaN    NaN  Zelkova: Japanese
# 32370  32371  1811868998            NaN    NaN          Elm: spp.
# 32371  32372  1783007585            NaN    NaN  Oak: Northern Red
# 32372  32373   799655446            NaN    NaN  Oak: Northern Red
# 32373  32374  2050431246            NaN    NaN  Zelkova: Japanese
# 32374  32375   798809421            NaN    NaN           Oak: Pin
# 32375  32376  1348438860            NaN    NaN         Maple: Red
# 32376  32377  1704127422            NaN    NaN         Maple: Red
#
#          scientific_name  height  width  growth_space_length  \
# 32362         Ulmus spp.     0.0    0.0                  0.0
# 32368      Quercus rubra     0.0    0.0                  0.0
# 32369    Zelkova serrata     0.0    0.0                  0.0
# 32370         Ulmus spp.     0.0    0.0                  0.0
# 32371      Quercus rubra     0.0    0.0                  0.0
# 32372      Quercus rubra     0.0    0.0                  0.0
# 32373    Zelkova serrata     0.0    0.0                  0.0
# 32374  Quercus palustris     0.0    0.0                  0.0
# 32375        Acer rubrum     0.0    0.0                  0.0
# 32376        Acer rubrum     0.0    0.0                  0.0
#
#        growth_space_width  ...      neighborhood  council_district  ward  \
# 32362                 0.0  ...  Allegheny Center               1.0  22.0
# 32368                 0.0  ...  Allegheny Center               1.0  22.0
# 32369                 0.0  ...  Allegheny Center               1.0  22.0
# 32370                 0.0  ...  Allegheny Center               1.0  22.0
# 32371                 0.0  ...  Allegheny Center               1.0  22.0
# 32372                 0.0  ...  Allegheny Center               1.0  22.0
# 32373                 0.0  ...  Allegheny Center               1.0  22.0
# 32374                 0.0  ...  Allegheny Center               1.0  22.0
# 32375                 0.0  ...  Allegheny Center               1.0  22.0
# 32376                 0.0  ...  Allegheny Center               1.0  22.0
#
#               tract public_works_division pli_division  police_zone  \
# 32362  4.200356e+10                   1.0         22.0          1.0
# 32368  4.200356e+10                   1.0         22.0          1.0
# 32369  4.200356e+10                   1.0         22.0          1.0
# 32370  4.200356e+10                   1.0         22.0          1.0
# 32371  4.200356e+10                   1.0         22.0          1.0
# 32372  4.200356e+10                   1.0         22.0          1.0
# 32373  4.200356e+10                   1.0         22.0          1.0
# 32374  4.200356e+10                   1.0         22.0          1.0
# 32375  4.200356e+10                   1.0         22.0          1.0
# 32376  4.200356e+10                   1.0         22.0          1.0
#
#        fire_zone   latitude  longitude
# 32362        1-6  40.455978 -80.003251
# 32368        1-6  40.455892 -80.003783
# 32369        1-6  40.455877 -80.003864
# 32370        1-6  40.455861 -80.003981
# 32371        1-6  40.455823 -80.004133
# 32372        1-6  40.455793 -80.004276
# 32373        1-6  40.455763 -80.004383
# 32374        1-6  40.455644 -80.004463
# 32375        1-6  40.455575 -80.004424
# 32376        1-6  40.455517 -80.004594
#
# [10 rows x 59 columns]

# %% [markdown]
# Grouping each tree by the neighborhood that it is located in

# %% [markdown]
# #### *Displaying the Counts*

# %%
df = df['neighborhood'].value_counts().sort_values(ascending=False)
df
# Out:
# neighborhood
# Squirrel Hill South    5073
# Highland Park          2941
# Squirrel Hill North    2083
# South Side Flats       1693
# Shadyside              1558
#                        ...
# Arlington Heights         5
# Esplen                    3
# Glen Hazel                2
# South Shore               2
# Hays                      1
# Name: count, Length: 90, dtype: int64

# %% [markdown]
# #### *Ranking Each Neighborhood*

# %%
df.plot(
    kind = 'bar',
    title = "Number of Registered Trees in Each Pittsburgh Neighborhood",
    xlabel = "Neighborhood",
    ylabel = "Number of Trees",
    figsize = (15,7),

)
plt.show()

# %% [markdown]
# Gives the whole count of all neighborhoods and all the trees in each. Pretty hard to read at this level so the next couple lines of code break them down into top 5 and bottom 5.

# %%
top5 = df.head(5)
top5.plot(
    kind='bar',
    title="Top 5 Neighborhoods by Number of Trees",
    figsize=(10, 5)
)
plt.show()

# %% [markdown]
# Top 5 neighborhoods by number of registered trees

# %%
bottom5 = df.tail(5)
bottom5.plot(
    kind='bar',
    title="Bottom 5 Neighborhoods by Number of Trees",
    figsize=(10, 5)
)
plt.show()

# %% [markdown]
# Bottom 5 Neighborhoods by number of registered trees

# %% [markdown]
# #### Number of Trees Dataset Conclusion

# %% [markdown]
# The neighborhoods with the highest number of registered trees are Squirrel Hill South, Highland Park, Squirrel Hill North, South Side Flats, and Shadyside. Based on the trees metric alone, my nomination for "best neighborhood" would have to be Squirrel Hill South since it has the most number of registered trees by far.
#
# The counts for the trees themselves might be misleading however since the dataset only includes the number of "registered" trees. This means that there are certain neighborhoods in which the dataset only has one or two entries. These neighborhoods don't actually only have one or two trees, it's just that the city hasn't registered more than only one or two trees. This was the only tree registry available in WPRDC so I didn't have any other options. But even then, I believe that this dataset is still representative considering that there is a reason why certain neighborhoods are able to get their trees registered. It likely indicates other positive qualities of the neighborhood (ability to work with the city).
#
# In terms of "best neighborhood" my choice differs from the group conclusion. While Beechview still has plenty of trees, it sits around the midpoint of my data. So it's not the best choice when it comes to number of trees, nor is it the worst. Beechview still has enough trees for me to be satisfied with the conclusion of it being best neighborhood considering its ranking within the other metrics.

# %% [markdown]
# ### **Dataset2: Number of Parks in Pittsburgh Neighborhoods**

# %%
parksData = pd.read_csv('https://data.wprdc.org/datastore/dump/fa329e3d-89ff-4708-8ddf-81bfedcad11d')

# %%
parksData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         209 non-null    int64
#  1   id                          209 non-null    int64
#  2   name                        209 non-null    object
#  3   type                        209 non-null    object
#  4   maintenance_responsibility  209 non-null    object
#  5   image                       63 non-null     object
#  6   neighborhood                209 non-null    object
#  7   council_district            209 non-null    int64
#  8   ward                        209 non-null    int64
#  9   tract                       209 non-null    int64
#  10  public_works_division       209 non-null    int64
#  11  pli_division                209 non-null    int64
#  12  police_zone                 209 non-null    int64
#  13  fire_zone                   209 non-null    object
#  14  latitude                    209 non-null    float64
#  15  longitude                   209 non-null    float64
# dtypes: float64(2), int64(8), object(6)
# memory usage: 26.3+ KB

# %%
parksData.columns
# Out:
# Index(['_id', 'id', 'name', 'type', 'maintenance_responsibility', 'image',
#        'neighborhood', 'council_district', 'ward', 'tract',
#        'public_works_division', 'pli_division', 'police_zone', 'fire_zone',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
parksData
# Out:
#      _id          id                     name        type  \
# 0      1  2111959181           Able Long Park        Park
# 1      2  1109513049  Albert Turk Graham Park        Park
# 2      3  1544096765               Alcoa Park        Park
# 3      4  1212681573        Allegheny Commons        Park
# 4      5   954863286   Allegheny Landing Park        Park
# ..   ...         ...                      ...         ...
# 204  205  1460363095           Woods Run Park        Park
# 205  206   930068146         Young Field Park        Park
# 206  207  1127012019              Zulema Park        Park
# 207  208  1719897212       Liberty Green Park        Park
# 208  241  1305573349         Esser Plaza Park  Open Space
#
#     maintenance_responsibility  \
# 0             Parks - Southern
# 1             Parks - Schenley
# 2             Parks - Northern
# 3             Parks - Northern
# 4             Parks - Northern
# ..                         ...
# 204           Parks - Northern
# 205           Parks - Northern
# 206           Parks - Schenley
# 207          Parks - Northeast
# 208           Parks - Southern
#
#                                                  image        neighborhood  \
# 0    https://tools.wprdc.org/images/pittsburgh/park...           Beechview
# 1    https://tools.wprdc.org/images/pittsburgh/park...    Crawford-Roberts
# 2                                                  NaN         North Shore
# 3                                                  NaN    Allegheny Center
# 4                                                  NaN         North Shore
# ..                                                 ...                 ...
# 204  https://tools.wprdc.org/images/pittsburgh/park...  Marshall-Shadeland
# 205                                                NaN  Marshall-Shadeland
# 206                                                NaN     Central Oakland
# 207                                                NaN        East Liberty
# 208                                                NaN    South Side Flats
#
#      council_district  ward        tract  public_works_division  pli_division  \
# 0                   4    19  42003192000                      5            19
# 1                   6     3  42003030500                      3             3
# 2                   1    22  42003563200                      6            22
# 3                   1    22  42003562700                      1            22
# 4                   1    22  42003563200                      6            22
# ..                ...   ...          ...                    ...           ...
# 204                 1    27  42003271500                      1            27
# 205                 1    27  42003271500                      1            27
# 206                 3     4  42003040500                      3             4
# 207                 9    11  42003111500                      2            11
# 208                 3    17  42003170200                      3            17
#
#      police_zone fire_zone   latitude  longitude
# 0              6      4-28  40.408118 -80.028197
# 1              2       2-1  40.440507 -79.984018
# 2              1      1-20  40.447481 -80.001017
# 3              1       1-7  40.453126 -80.009158
# 4              1      1-20  40.447184 -80.002907
# ..           ...       ...        ...        ...
# 204            1      1-14  40.476383 -80.029253
# 205            1      1-14  40.472963 -80.032768
# 206            4      2-14  40.435693 -79.957048
# 207            5      3-10  40.462773 -79.919314
# 208            3      4-24  40.428564 -79.986239
#
# [209 rows x 16 columns]

# %% [markdown]
# #### **Removing Columns**

# %%
removeColumns = ['_id', 'id', 'maintenance_responsibility', 'image', 'council_district', 'ward', 'tract', 'public_works_division', 'pli_division', 'police_zone', 'fire_zone', 'latitude', 'longitude']
parksData.drop(columns = removeColumns, inplace = True)

# %% [markdown]
# #### **Count of Parks, Traffic Island/Medians, Building Grounds, Monument/Memorials, and Open Space Within Each Neighborhood.**

# %%
(parksData
    .assign(total = parksData.groupby('neighborhood')['type'].transform('count'),
            count = parksData.groupby(['neighborhood', 'type'])['type'].transform('count'))   
    .drop_duplicates(subset = ['type', 'neighborhood'])
    .sort_values(by = ['total', 'neighborhood', 'count'], ascending = (False, True, False))
    .set_index(['neighborhood', 'type'])
    [['name', 'count', 'total']]
)
# Out:
#                                                                       name  \
# neighborhood              type
# East Liberty              Traffic Island/Median             Amber Triangle
#                           Park                           East Liberty Park
# Central Business District Traffic Island/Median              Bedford Strip
#                           Park                   Allegheny Riverfront Park
#                           Open Space                    Market Square Park
# ...                                                                    ...
# Squirrel Hill North       Park                               Wightman Park
# Stanton Heights           Park                                  Dinan Park
# Upper Hill                Park                     Robert E. Williams Park
# West Oakland              Park                    Shalane's Play Yard Park
# Windgap                   Park                              Chartiers Park
#
#                                                  count  total
# neighborhood              type
# East Liberty              Traffic Island/Median      8     12
#                           Park                       4     12
# Central Business District Traffic Island/Median      5     10
#                           Park                       3     10
#                           Open Space                 2     10
# ...                                                ...    ...
# Squirrel Hill North       Park                       1      1
# Stanton Heights           Park                       1      1
# Upper Hill                Park                       1      1
# West Oakland              Park                       1      1
# Windgap                   Park                       1      1
#
# [104 rows x 3 columns]

# %% [markdown]
# #### **Filter Non-Park Types**

# %% [markdown]
# The reason I am removing every type but the parks is because oftentimes the other types (e.g. monument, memorials, traffic island, medians, open space, and building grounds) are not good representations of parks.
# * Traffic islands/medians are not resembalance of parks
# * Monuments are not resembalance of parks
# * Building grounds often included buildings such as nursing homes or other activity centers
# * Open spaces often included plazas (no grass), small get-together spots, etc. Not close enough to the 'parks' type

# %% [markdown]
# #### **Count and Name of Parks**

# %%
(parksData
    .query('type == "Park"')  
    .assign(count = lambda df: df.groupby('neighborhood')['type'].transform('count'))
    .set_index(['neighborhood', 'name'])
    .sort_values(by = ['count', 'neighborhood', 'name'], ascending = (False, True, True))
    [['type', 'count']]
)
# Out:
#                                                             type  count
# neighborhood   name
# Beechview      Able Long Park                               Park      6
#                Alton Park                                   Park      6
#                Beechview Healthy Active Living Center Park  Park      6
#                Pauline Park                                 Park      6
#                Tropical Park                                Park      6
# ...                                                          ...    ...
# Swisshelm Park Swisshelm Park                               Park      1
# Upper Hill     Robert E. Williams Park                      Park      1
# West End       Wabash Park                                  Park      1
# West Oakland   Shalane's Play Yard Park                     Park      1
# Windgap        Chartiers Park                               Park      1
#
# [153 rows x 2 columns]

# %% [markdown]
# #### **Final Parks DataFrame**

# %%
parksFinal = parksData

# %%
parksFinal =( parksFinal
            .query('type == "Park"')  
            .assign(count = lambda df: df.groupby('neighborhood')['type'].transform('count'))
            .set_index(['neighborhood', 'name'])
            .sort_values(by = ['count', 'neighborhood', 'name'], ascending = (False, True, True))
            [['type', 'count']]
            )

# %%
parksFinal
# Out:
#                                                             type  count
# neighborhood   name
# Beechview      Able Long Park                               Park      6
#                Alton Park                                   Park      6
#                Beechview Healthy Active Living Center Park  Park      6
#                Pauline Park                                 Park      6
#                Tropical Park                                Park      6
# ...                                                          ...    ...
# Swisshelm Park Swisshelm Park                               Park      1
# Upper Hill     Robert E. Williams Park                      Park      1
# West End       Wabash Park                                  Park      1
# West Oakland   Shalane's Play Yard Park                     Park      1
# Windgap        Chartiers Park                               Park      1
#
# [153 rows x 2 columns]

# %% [markdown]
# #### **Graph of All Neighborhoods**

# %%
(
    parksFinal
        .reset_index()
        .drop_duplicates(subset = 'neighborhood')
        .set_index('neighborhood')
        .drop(columns = ['name', 'type'])
        .sort_values(by = 'count')
        .plot.barh(figsize = (15,15))
    
)
# Out:
# <Axes: ylabel='neighborhood'>

# %% [markdown]
# #### **Graph of Best 5 Neighborhoods**

# %%
(
    parksFinal
        .reset_index()
        .drop_duplicates(subset = 'neighborhood')
        .set_index('neighborhood')
        .drop(columns = ['name', 'type'])
        .sort_values(by = 'count')
        .tail()
        .plot.barh()
    
)
# Out:
# <Axes: ylabel='neighborhood'>

# %% [markdown]
# #### **Graph of Worst 5 Neighborhoods**

# %%
(
    parksFinal
        .reset_index()
        .drop_duplicates(subset = 'neighborhood')
        .set_index('neighborhood')
        .drop(columns = ['name', 'type'])
        .sort_values(by = 'count')
        .head()
        .plot.barh()
    
)
# Out:
# <Axes: ylabel='neighborhood'>

# %% [markdown]
# #### **Parks Data Conclusion**

# %% [markdown]
# Using a dataset containing the neighborhood parks in Pittsburgh, I concluded that Beechview and South Side Slopes is the best neighborhood based on the sheer number of parks. To come to this conclusion I removed unneccesary columns, removed irrelevant "types", combined neighborhoods based on cardinal directions, and counted the number of parks within each neighborhood. Beechview and South Side Slopes had the most at 6, followed by Hazelwood, Troy Hill, and Mount Washington at 5.
#
# I was pretty suprised that South Side Slopes came out on top because I expected it to be much lower. I would have guessed Squirrel Hill as the number one spot because it includes two of the largest parks in Pittsburgh, Frick and Schenley. The reason it did not appear in the top 5 is due to the datasets lack of any acreage metric. Incorporating an acreage metric would drastically change the results, most likely making my favorite neighborhood, Squirrel Hill, number one. This is especially true when Frick and Schenley park are 1000+ acres, while Beechview's parks are 100+ acres and South Side Slope's parks are 60+ acres.

# %% [markdown]
# ### **Dataset3 Tax Delinquancy and Analysis**

# %%
import pandas as pd

df = pd.read_csv("datasetpgh.csv")
df.head()
# Out:
#        _id               pin             address    billing_city  \
# 0  2655445  0008A00051000000     829 WESTERN AVE  PITTSBURGH, PA
# 1  2655446  0022S00108000000     909 W NORTH AVE      TUCSON, AZ
# 2  2655447  0003N00226000000  21 BELTZHOOVER AVE      POMONA, CA
# 3  2655448  0013J00138000000       1817 WAITE ST   ALIQUIPPA, PA
# 4  2655449  0032D00208000000         101 EADS ST  PITTSBURGH, PA
#
#    current_delq_tax  current_delq_pi  prior_years  prior_delq_tax  \
# 0           9565.84              0.0            0             0.0
# 1            499.37              0.0            0             0.0
# 2             23.53              0.0            0             0.0
# 3            227.56              0.0            0             0.0
# 4            556.55              0.0            0             0.0
#
#    prior_delq_pi state_description    neighborhood  council_district  ward  \
# 0            0.0       Residential  Allegheny West               1.0  22.0
# 1            0.0       Residential  Allegheny West               1.0  22.0
# 2            0.0       Residential       Allentown               3.0  18.0
# 3            0.0       Residential       Arlington               3.0  16.0
# 4            0.0       Residential       Arlington               3.0  16.0
#
#    public_works_division  pli_division  police_zone fire_zone  longitude  \
# 0                    1.0          22.0          1.0       1-7 -80.015129
# 1                    1.0          22.0          1.0       1-7 -80.017415
# 2                    4.0          18.0          3.0       4-5 -79.997231
# 3                    4.0          16.0          3.0       4-8 -79.979810
# 4                    4.0          16.0          3.0      4-13 -79.968412
#
#     latitude
# 0  40.451972
# 1  40.453258
# 2  40.425144
# 3  40.417336
# 4  40.412595

# %% [markdown]
# Here I am importing my data set

# %%
df.columns
# Out:
# Index(['_id', 'pin', 'address', 'billing_city', 'current_delq_tax',
#        'current_delq_pi', 'prior_years', 'prior_delq_tax', 'prior_delq_pi',
#        'state_description', 'neighborhood', 'council_district', 'ward',
#        'public_works_division', 'pli_division', 'police_zone', 'fire_zone',
#        'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# Here I get all of the data into columns for how they are described

# %%
sorted_data.plot(
    kind='bar',
    title="Total Property Tax Delinquency by Neighborhood",
    xlabel="Neighborhood",
    ylabel="Total Delinquent Tax",
    figsize=(12,6),
    rot=90
)
# Out:
# <Axes: title={'center': 'Total Property Tax Delinquency by Neighborhood'}, xlabel='Neighborhood', ylabel='Total Delinquent Tax'>

# %% [markdown]
# Here I put all the data into a graph

# %%
grouped = df.groupby("neighborhood")["current_delq_tax"].sum()
# Sort values
sorted_data = grouped.sort_values()

# 5 LOWEST (best)
print("Top 5 BEST (Lowest Tax Delinquency):")
print(sorted_data.head(5))

# 5 HIGHEST (worst)
print("\nTop 5 WORST (Highest Tax Delinquency):")
print(sorted_data.tail(5))
# Out:
# Top 5 BEST (Lowest Tax Delinquency):
# neighborhood
# Allegheny Center     0.0
# Bedford Dwellings    0.0
# Banksville           0.0
# Arlington Heights    0.0
# Beechview            0.0
# Name: current_delq_tax, dtype: float64
#
# Top 5 WORST (Highest Tax Delinquency):
# neighborhood
# Crawford-Roberts             27207.20
# Bloomfield                   30001.66
# East Allegheny               37647.55
# North Oakland                59098.55
# Central Business District    90718.94
# Name: current_delq_tax, dtype: float64

# %% [markdown]
# Now I have to group the data that I need which is the neighborhoods and the current tax delinquency. Then I sort them all by value and scrape then until I have the top 5 and the bottom 5 for the Highest and Lowest tax delinquency

# %% [markdown]
# Here I took the 5 Best ones and graphed them on a bar graph

# %%
lowest10 = sorted_data.head(10)

lowest10.plot(
    kind='bar',
    title="Top 10 Best Neighborhoods (Lowest Tax Delinquency)",
    xlabel="Neighborhood",
    ylabel="Total Delinquent Tax",
    figsize=(10,5),
    rot=45
)
# Out:
# <Axes: title={'center': 'Top 10 Best Neighborhoods (Lowest Tax Delinquency)'}, xlabel='Neighborhood', ylabel='Total Delinquent Tax'>

# %% [markdown]
# Here I took the 5 Worst ones and graphed them on a bar graph

# %% [markdown]
# My

# %%
highest5 = sorted_data.tail(10)

highest5.plot(
    kind='bar',
    title="Top 5 Worst Neighborhoods (Highest Tax Delinquency)",
    xlabel="Neighborhood",
    ylabel="Total Delinquent Tax",
    figsize=(10,5),
    rot=45
)
# Out:
# <Axes: title={'center': 'Top 5 Worst Neighborhoods (Highest Tax Delinquency)'}, xlabel='Neighborhood', ylabel='Total Delinquent Tax'>

# %% [markdown]
# **Tax Deliquency Conclusion :**
#
# With all the data I couldn’t come to a conclusion to a neighborhood that is clearly the best through only my data set. Though I was able narrow down the list of the best possible places and rule out a lot of neighborhoods. So with the help of my group members data sets we can put everything together to pick the number 1 neighborhood which I say is Beechview. It's tied for the number one spot on my data set and ranks highly amongst the other data sets. It's a good data set with a hyper specific data set so theres little to no room to interate the data diffrently then how I did it which makes me even mire confident that Beechview is a great choice

# %% [markdown]
# ### **Dataset4 Number of Condemned and Dead-End Properties Per Neighborhood in Pittsburgh**

# %%
import pandas as pd
# %matplotlib inline

data = pd.read_csv("condemned_properties.csv")

# %% [markdown]
# #### C/D-E Prop - Data Gathering: Here, different sets of data are calculated to prove which neighborhood has the least and less serious run-down buildings.

# %%
# This dataset just holds the total number of condemned/dead-end properties per neighborhood
nh = data['neighborhood'].value_counts().sort_values(ascending=True)

# This dataset holds the number of failed inspections of those properties per neighborhood
nh_fails = data[data['latest_inspection_result']=='Fail']
nh_fails = nh_fails['neighborhood'].value_counts().sort_values(ascending=True)

# This dataset holds the number of passed inspections of those properties per neighborhood
nh_passes = data[data['latest_inspection_result']=='Pass']
nh_passes = nh_passes['neighborhood'].value_counts().sort_values(ascending=False)

# This dataset holds the average rate of having a passing inspection per neighborhood
nh_avgs = nh_passes / nh
nh_avgs = nh_avgs.fillna(0)
nh_avgs = nh_avgs.sort_values(ascending=False)

# This dataset holds the cumulative inspection scores of each neighborhood
nh_scores = data.groupby('neighborhood')['latest_inspection_score'].sum().sort_values(ascending=False)

# This dataset holds the average inspection scores of each neighborhood
nh_score_avgs = data.groupby('neighborhood')['latest_inspection_score'].mean().sort_values(ascending=False)


# Big Average of all graph data

t = 1.0 - (nh / nh.max())
f = 1.0 - (nh_fails / nh_fails.max())
p = nh_passes / nh_passes.max()
a = nh_avgs / nh_avgs.max()
s = nh_scores / nh_scores.max()
v = nh_score_avgs / nh_score_avgs.max()

data_sum = t + f + p #+ a + s + v
tf = (t + f).fillna(0)
tfp = (tf + p).fillna(0)
tfpa = (tfp + a).fillna(0)
tfpas = (tfpa + s).fillna(0)
tfpasv = (tfpas + v).fillna(0)

total_nh_avgs = tfpasv / 6 #6
total_nh_avgs = total_nh_avgs.sort_values(ascending=False)

# %% [markdown]
# #### C/D-E Prop - Example Graphs: These graphs condense all the information into just a few neighborhoods to be more easily digestible

# %%
# All of the condemned and dead-end properties per neighborhood
nh.plot(
    kind = "bar",
    title="Total Number of Condemned/Dead-End Properties Per Neighborhood in Pittsburgh",
    xlabel="Neighborhood",
    ylabel="Condemned/Dead-End Properties",
    figsize=(20,5)
)
# Out:
# <Axes: title={'center': 'Total Number of Condemned/Dead-End Properties Per Neighborhood in Pittsburgh'}, xlabel='Neighborhood', ylabel='Condemned/Dead-End Properties'>

# %%
# Gets 7 highest amounts of C/D-E Properties
all_check = nh.tail(7)
all_check.plot(
    kind = "bar",
    title="Total Number of Condemned/Dead-End Properties Per Neighborhood in Pittsburgh",
    xlabel="Neighborhood",
    ylabel="Condemned/Dead-End Properties",
    figsize=(5,3)
)
# Out:
# <Axes: title={'center': 'Total Number of Condemned/Dead-End Properties Per Neighborhood in Pittsburgh'}, xlabel='Neighborhood', ylabel='Condemned/Dead-End Properties'>

# %%
# Gets 10 highest amounts of Inspection Passes of C/D-E Properties
passes_check = nh_passes.head(10)
passes_check.plot(
    kind = "bar",
    title="Number of Passing Inspections of Condemned/Dead-End Properties Per Neighborhood in Pittsburgh",
    xlabel="Neighborhood",
    ylabel="Passing Inspections",
    figsize=(5,3)
)
# Out:
# <Axes: title={'center': 'Number of Passing Inspections of Condemned/Dead-End Properties Per Neighborhood in Pittsburgh'}, xlabel='Neighborhood', ylabel='Passing Inspections'>

# %%
# Gets 10 random neighborhood amounts of Inspection Fails of C/D-E Properties
fails_check = nh_fails.sample(10)
fails_check = fails_check.sort_values(ascending=True)
fails_check.plot(
    kind = "bar",
    title="Number of Failed Inspections of Condemned/Dead-End Properties Per Neighborhood in Pittsburgh",
    xlabel="Neighborhood",
    ylabel="Failed Inspections",
    figsize=(5,3)
)
# Out:
# <Axes: title={'center': 'Number of Failed Inspections of Condemned/Dead-End Properties Per Neighborhood in Pittsburgh'}, xlabel='Neighborhood', ylabel='Failed Inspections'>

# %%
# 10 random neighborhood average score for all tests
tot_avgs_check = total_nh_avgs.sample(10) 
tot_avgs_check = tot_avgs_check.sort_values(ascending=False)
tot_avgs_check.plot(
    kind = "bar",
    title="Average Test Score of Condemned/Dead-End Properties Per Neighborhood in Pittsburgh",
    xlabel="Neighborhood",
    ylabel="Average Test Scores",
    figsize=(5,3)
)
# Out:
# <Axes: title={'center': 'Average Test Score of Condemned/Dead-End Properties Per Neighborhood in Pittsburgh'}, xlabel='Neighborhood', ylabel='Average Test Scores'>

# %%
# The total graph for the dataset that averages all the positions of all the previous condemned/dead-end filtered data
total_nh_avgs.plot(
    kind = "bar",
    title="Average Test Score of Condemned/Dead-End Properties Per Neighborhood in Pittsburgh",
    xlabel="Neighborhood",
    ylabel="Average Test Scores for Condemned/Dead-End Properties",
    figsize=(20,5)
)
# Out:
# <Axes: title={'center': 'Average Test Score of Condemned/Dead-End Properties Per Neighborhood in Pittsburgh'}, xlabel='Neighborhood', ylabel='Average Test Scores for Condemned/Dead-End Properties'>

# %% [markdown]
# #### C/D-E Prop - Conclusion
# The metrics for the Condemned and Dead-End Properties dataset name the best locations as: Summer Hill, Middle Hill, and Northview Heights (although, South Shore and Swisshelm Park are also contenders; this is explained later.) The choice to have these as the best is supported by the data I gathered that averaged all the scores of all the different ways I filtered the data: just the amount of condemned/dead-end houses, the number of passes/fails, the inspection scores, and the averages of all of them. So, the neighborhoods that did the best overall of having the least run-down and the least amount of run-down houses would appear on the dataset.
#
# However, South Shore and Swisshelm Park could be considered the best neighborhoods for this metric. Since the final cummultative dataset uses data from all my filtered datasets, it does not include if certain neighborhoods had no data that would pertain to some of the datasets: some neighborhoods had no inspection or inspection score data. So, neighborhoods like South Shore and Swisshelm Park were not considered as highly in the final dataset. Therefore, South Shore and Swisshelm Park should be equally as considered for best neighborhood on my data.
#
# But, the best neighborhoods found with my data is the not the final conclusion of the group. Beechview, while not being the best with the dataset, is higher. Beechview averages top 1/3 for all the tests (even if it lands in the lower 1/3 of least amount of properties.) So, with Beechview being the best for multiple other datasets, Beechvew is considered the best neighborhood with the four datasets used by this group
